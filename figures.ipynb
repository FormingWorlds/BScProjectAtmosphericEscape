# %% [markdown]
# # All Figures
# ##### BSc Thesis Renske Beuker
# This plot shows all figures ysing the .py files as code

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Figure 14 recreation

# %%
from radius_cutoffs import *

from figure14 import r, MT_Mp, r_min, r_cap, r_gi

plt.figure(figsize=(10,8))
plt.plot(r, MT_Mp, color='navy')
plt.xlabel('r [m]')
plt.axvline(r_min, label=r'$r_{min}$', color='tomato', linestyle='--', alpha=0.7)
plt.axvline(r_cap, label=r'$r_{cap}$', color='orange', linestyle='-.', alpha=0.7)
plt.axvline(r_gi,label=r'$r_{gi}$' , color='turquoise', linestyle=':', alpha=0.7)
plt.ylabel(r'$M_T/M_{earth}$')
plt.title(r'Total impactor mass $M_T$ needed to eject atmosphere as function of impactor radius r (fig 14)')
plt.xscale('log')
plt.yscale('log')
plt.legend()
# plt.savefig('Mtotal_vs_impactor_rad')
plt.show()

# %% [markdown]
# #### Ejected per impactor mass shown for radius based on fig 14
#
#
# # ADD atmosphere mass in function?

# %%
from ejected_mass import M_ejected
from Earth_constants import M_atm

M_ej = M_ejected(r_min, r) * M_atm # [kg]

plt.figure(figsize=(10,8))
plt.plot(r, M_ej, color='navy')
plt.xlabel('Impactor radius r [m]')
plt.axvline(r_min, label=r'$r_{min}$', color='tomato', linestyle='--', alpha=0.7)
plt.axvline(r_cap, label=r'$r_{cap}$', color='orange', linestyle='-.', alpha=0.7)
plt.axvline(r_gi,label=r'$r_{gi}$' , color='turquoise', linestyle=':', alpha=0.7)
plt.ylabel(r'$M_{eject} [kg] / m_{imp}$')
plt.title(r'Ejected atmosphere mass as function of impactor radius r (fig 14)')
plt.xscale('log')
plt.yscale('log')
plt.legend()
# plt.savefig('Ejected_mass_vs_rad')
plt.show()

# %% [markdown]
# # Global loss

# %%
# from giant_impacts_fractional_loss import x, X_loss

# m_imp_Mars = 6.4e23   # mass of impactor: Mars (kg)
# M_Earth = 5.98e24     # mass of planet: Earth (kg)

# m_M = m_imp_Mars / M_Earth

# gamma_adi = 4/3
# gamma_iso = 5/3

# X_loss_adia = X_loss(x, gamma_adi)
# X_loss_iso = X_loss(x, gamma_iso)

# plt.figure(figsize=(10,8))
# plt.plot(x, X_loss_iso, color='navy', label='Isothermal global mass loss')
# plt.plot(x, X_loss_adia, color='orange', label='Adiabatic global mass loss')
# plt.axvline(m_M, color='red', label=r'$m_{imp}/M_{planet}$', linestyle='--')
# plt.xlabel(r'$v_{imp}m/v_{esc}M$')
# plt.ylabel(r'$X_{loss}$')
# plt.title(r'Fractional global mass loss $X_{loss}$')
# plt.legend()
# # plt.savefig('Mtotal_vs_impactor_rad')
# plt.show()

# plt.axvline(m_M, label=r'$m_{imp}/M_{planet}$ for Mars-like impactor and Earth-like planet', linestyle='--')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
from giant_impacts_fractional_loss import X_loss

gamma_adia = 4/3
gamma_iso = 5/3

X_loss_adia, x = X_loss(gamma_adia)
X_loss_iso, x = X_loss(gamma_iso)

plt.figure(figsize=(6,5))
plt.style.use("tableau-colorblind10")
plt.plot(x, X_loss_iso, label='Isothermal global mass loss')
plt.plot(x, X_loss_adia, label='Adiabatic global mass loss')
plt.xlabel(r'$v_{imp}m/v_{esc}M$')
plt.ylabel(r'$X_{loss}$')
plt.title(r'Fractional global mass loss $X_{loss}$')
plt.legend()
# plt.savefig('Fractional_global_loss.png')
plt.show()

# %%
from properties import total_M_atmos

# %%
from open_PROTEUS_csv import open_PROTEUS_csv, open_bulk_PROTEUS

# %%
# profiles 1M atmospheres

H2_1M_1F = open_PROTEUS_csv("PROTEUS_data/H2_atmosphere_1_M_earth_1_F_earth.csv", sep='\t')
H2_1M_1000F = open_PROTEUS_csv("PROTEUS_data/H2_atmosphere_1_M_earth_1000_F_earth.csv", sep='\t')

H2O_1M_1F = open_PROTEUS_csv("PROTEUS_data/H2O_atmosphere_1_M_earth_1_F_earth.csv", sep='\t')
H2O_1M_1000F = open_PROTEUS_csv("PROTEUS_data/H2O_atmosphere_1_M_earth_1000_F_earth.csv", sep='\t')

N2_1M_1F = open_PROTEUS_csv("PROTEUS_data/N2_atmosphere_1_M_earth_1_F_earth.csv", sep='\t')
N2_1M_1000F = open_PROTEUS_csv("PROTEUS_data/N2_atmosphere_1_M_earth_1000_F_earth.csv", sep='\t')

CO2_1M_1F = open_PROTEUS_csv("PROTEUS_data/CO2_atmosphere_1_M_earth_1_F_earth.csv", sep='\t')
CO2_1M_1000F = open_PROTEUS_csv("PROTEUS_data/CO2_atmosphere_1_M_earth_1000_F_earth.csv", sep='\t')


# bulk 1M properties
bulk_H2_1M = open_bulk_PROTEUS("PROTEUS_data/Bulk_properties/planet_bulk_properties_H2_atmospheres_1_M_earth.csv", sep='\t')

bulk_H2O_1M = open_bulk_PROTEUS("PROTEUS_data/Bulk_properties/planet_bulk_properties_H2O_atmospheres_1_M_earth.csv", sep='\t')

bulk_N2_1M = open_bulk_PROTEUS("PROTEUS_data/Bulk_properties/planet_bulk_properties_N2_atmospheres_1_M_earth.csv", sep='\t')

bulk_CO2_1M = open_bulk_PROTEUS("PROTEUS_data/Bulk_properties/planet_bulk_properties_N2_atmospheres_1_M_earth.csv", sep='\t')

# %%
M_atm_H2_1M_1F = total_M_atmos(H2_1M_1F[0], H2_1M_1F[1], bulk_H2_1M[2])
M_atm_H2_1M_1000F = total_M_atmos(H2_1M_1000F[0], H2_1M_1000F[1], bulk_H2_1M[3])

M_atm_H2O_1M_1F = total_M_atmos(H2O_1M_1F[0], H2O_1M_1F[1], bulk_H2O_1M[2])
M_atm_H2O_1M_1000F = total_M_atmos(H2O_1M_1000F[0], H2O_1M_1000F[1], bulk_H2O_1M[3])

M_atm_N2_1M_1F = total_M_atmos(N2_1M_1F[0], N2_1M_1F[1], bulk_N2_1M[2])
M_atm_N2_1M_1000F = total_M_atmos(N2_1M_1000F[0], N2_1M_1000F[1], bulk_N2_1M[3])

M_atm_CO2_1M_1F = total_M_atmos(CO2_1M_1F[0], CO2_1M_1F[1], bulk_CO2_1M[2])
M_atm_CO2_1M_1000F = total_M_atmos(CO2_1M_1000F[0], CO2_1M_1000F[1], bulk_CO2_1M[3])

# %%
flux_legend = [
    Line2D([0], [0], color="black", linestyle="-",  label=r"1 $F_{\odot}$"),
    Line2D([0], [0], color="black", linestyle="--", label=r"1000 $F_{\odot}$")
]

elements_legend = [
    Line2D([0], [0], color="#006BA4", label="H2"),
    Line2D([0], [0], color="#FF800E",   label="H2O"),
    Line2D([0], [0], color="#ABABAB",  label="N2"),
    Line2D([0], [0], color="#595959", label="CO2")
]

plt.legend(handles = flux_legend + elements_legend, title="Legend")

# %%
plt.figure(figsize=(6,5))
plt.style.use("tableau-colorblind10")

plt.plot(x, (X_loss_adia*M_atm_H2_1M_1F), color='#006BA4')
plt.plot(x, (X_loss_adia*M_atm_H2_1M_1000F), color='#006BA4', linestyle='--')
plt.plot(x, (X_loss_adia*M_atm_H2O_1M_1F), color='#FF800E')
plt.plot(x, (X_loss_adia*M_atm_H2O_1M_1000F), color='#FF800E', linestyle='--')
plt.plot(x, (X_loss_adia*M_atm_N2_1M_1F), color='#ABABAB')
plt.plot(x, (X_loss_adia*M_atm_N2_1M_1000F), color='#ABABAB', linestyle='--')
plt.plot(x, (X_loss_adia*M_atm_CO2_1M_1F), color='#595959')
plt.plot(x, (X_loss_adia*M_atm_CO2_1M_1000F), color='#595959', linestyle='--')

plt.xlabel(r'$v_{imp}m/v_{esc}M$')
plt.ylabel(r'Mass loss [kg]')
plt.yscale('log')
plt.title(r'Global mass loss for planets of $1\ M_{Earth}$')


flux_legend = [
    Line2D([0], [0], color="black", linestyle="-",  label=r"1 $F_{\odot}$"),
    Line2D([0], [0], color="black", linestyle="--", label=r"1000 $F_{\odot}$")
]

divider = Line2D([0], [0], color="white", linestyle="-", linewidth=1, label=" ")

elements_legend = [
    Line2D([0], [0], color="#006BA4", label="H2"),
    Line2D([0], [0], color="#FF800E",   label="H2O"),
    Line2D([0], [0], color="#ABABAB",  label="N2"),
    Line2D([0], [0], color="#595959", label="CO2")
]

plt.legend(handles = flux_legend + [divider] + elements_legend, loc = 'lower right', bbox_to_anchor=(1.3, 0.5), title="Legend")


#plt.savefig('Global mass loss 1M.png', bbox_inches="tight")
plt.show()

# %%
# profiles 10M atmospheres

H2_10M_1F = open_PROTEUS_csv("PROTEUS_data/H2_atmosphere_10_M_earth_1_F_earth.csv", sep='\t')
H2_10M_1000F = open_PROTEUS_csv("PROTEUS_data/H2_atmosphere_10_M_earth_1000_F_earth.csv", sep='\t')

H2O_10M_1F = open_PROTEUS_csv("PROTEUS_data/H2O_atmosphere_10_M_earth_1_F_earth.csv", sep='\t')
H2O_10M_1000F = open_PROTEUS_csv("PROTEUS_data/H2O_atmosphere_10_M_earth_1000_F_earth.csv", sep='\t')

N2_10M_1F = open_PROTEUS_csv("PROTEUS_data/N2_atmosphere_10_M_earth_1_F_earth.csv", sep='\t')
N2_10M_1000F = open_PROTEUS_csv("PROTEUS_data/N2_atmosphere_10_M_earth_1000_F_earth.csv", sep='\t')

CO2_10M_1F = open_PROTEUS_csv("PROTEUS_data/CO2_atmosphere_10_M_earth_1_F_earth.csv", sep='\t')
CO2_10M_1000F = open_PROTEUS_csv("PROTEUS_data/CO2_atmosphere_10_M_earth_1000_F_earth.csv", sep='\t')


# bulk 10M properties
bulk_H2_10M = open_bulk_PROTEUS("PROTEUS_data/Bulk_properties/planet_bulk_properties_H2_atmosphere_10_M_earth (1).csv", sep='\t')

bulk_H2O_10M = open_bulk_PROTEUS("PROTEUS_data/Bulk_properties/planet_bulk_properties_H2O_atmosphere_10_M_earth.csv", sep='\t')

bulk_N2_10M = open_bulk_PROTEUS("PROTEUS_data/Bulk_properties/planet_bulk_properties_N2_atmosphere_10_M_earth.csv", sep='\t')

bulk_CO2_10M = open_bulk_PROTEUS("PROTEUS_data/Bulk_properties/planet_bulk_properties_CO2_atmosphere_10_M_earth.csv", sep='\t')

# %%
M_atm_H2_10M_1F = total_M_atmos(H2_10M_1F[0], H2_10M_1F[1], bulk_H2_10M[2])
M_atm_H2_10M_1000F = total_M_atmos(H2_10M_1000F[0], H2_10M_1000F[1], bulk_H2_10M[3])

M_atm_H2O_10M_1F = total_M_atmos(H2O_10M_1F[0], H2O_10M_1F[1], bulk_H2O_10M[2])
M_atm_H2O_10M_1000F = total_M_atmos(H2O_10M_1000F[0], H2O_10M_1000F[1], bulk_H2O_10M[3])

M_atm_N2_10M_1F = total_M_atmos(N2_10M_1F[0], N2_10M_1F[1], bulk_N2_10M[2])
M_atm_N2_10M_1000F = total_M_atmos(N2_10M_1000F[0], N2_10M_1000F[1], bulk_N2_10M[3])

M_atm_CO2_10M_1F = total_M_atmos(CO2_10M_1F[0], CO2_10M_1F[1], bulk_CO2_10M[2])
M_atm_CO2_10M_1000F = total_M_atmos(CO2_10M_1000F[0], CO2_10M_1000F[1], bulk_CO2_10M[3])

# %%
plt.figure(figsize=(6,5))
plt.style.use("tableau-colorblind10")

plt.plot(x, (X_loss_adia*M_atm_H2_10M_1F), color='#006BA4')
plt.plot(x, (X_loss_adia*M_atm_H2_10M_1000F), color='#006BA4', linestyle='--')
plt.plot(x, (X_loss_adia*M_atm_H2O_10M_1F), color='#FF800E')
plt.plot(x, (X_loss_adia*M_atm_H2O_10M_1000F), color='#FF800E', linestyle='--')
plt.plot(x, (X_loss_adia*M_atm_N2_10M_1F), color='#ABABAB')
plt.plot(x, (X_loss_adia*M_atm_N2_10M_1000F), color='#ABABAB', linestyle='--')
plt.plot(x, (X_loss_adia*M_atm_CO2_10M_1F), color='#595959')
plt.plot(x, (X_loss_adia*M_atm_CO2_10M_1000F), color='#595959', linestyle='--')

plt.xlabel(r'$v_{imp}m/v_{esc}M$')
plt.ylabel(r'Mass loss [kg]')
plt.yscale('log')
plt.title(r'Global mass loss for planets of $10\ M_{Earth}$')


flux_legend = [
    Line2D([0], [0], color="black", linestyle="-",  label=r"1 $F_{\odot}$"),
    Line2D([0], [0], color="black", linestyle="--", label=r"1000 $F_{\odot}$")
]

divider = Line2D([0], [0], color="white", linestyle="-", linewidth=1, label=" ")

elements_legend = [
    Line2D([0], [0], color="#006BA4", label="H2"),
    Line2D([0], [0], color="#FF800E",   label="H2O"),
    Line2D([0], [0], color="#ABABAB",  label="N2"),
    Line2D([0], [0], color="#595959", label="CO2")
]

plt.legend(handles = flux_legend + [divider] + elements_legend, loc = 'lower right', bbox_to_anchor=(1.3, 0.5), title="Legend")


# plt.savefig('Global mass loss 10M.png', bbox_inches="tight")
plt.show()

# %% [markdown]
# ## PROTEUS figures

# %%
from Earth_constants import M, R
from open_PROTEUS_csv import *
from total_M_atmos import *

# %%
# filename = "H2_atmosphere_1_M_earth_1_F_earth - H2_atmosphere_1_M_earth_1_F_earth.csv"

# rho_H2_1_1, z_H2_1_1 = open_PROTEUS_csv(filename)

# %%
# M_H2_1_1 = total_M_atmos(z_H2_1_1, rho_H2_1_1, R)
# print(M_H2_1_1)

# %%
# radii different profiles:

R_10M = 118500600 # radius planet of 10 Earth masses in [m] for all compositions

R_1M_H2 = 6311626.946 # [m]

R_1M_CO2 = 6309508.803 # [m]

R_1M_N2 = 6307338.202 # [m]

R_1M_H20_1F = 6311758.084 # [m]
R_1M_H20_1000F = 6312025.373 # [m]

# %%
# import pandas as pd

# df_1M_1F_H2 = pd.read_csv("H2_atmosphere_1_M_earth_1_F_earth - H2_atmosphere_1_M_earth_1_F_earth.csv")
# print(df_1M_1F_H2.head())

# #rho_H2_1M_1F = df_1M_1F_H2["Density [kg/m3]"].tolist()
# # rho_H2_1M_1F = np.array(rho_H2_1M_1F)[-1]

# %%
# df_10M_1F_H2 = pd.read_csv("H2_atmosphere_10_M_earth_1_F_earth.csv", sep="\t")
# print (df_10M_1F_H2.head())

# #rho_H2_10M_1F = df_10M_1F_H2["Density [kg/m3]"].tolist()

# %%
# df_10M_1F_H2 = pd.read_csv("H2_atmosphere_10_M_earth_1_F_earth.csv")
#rho_H2_10M_1F = df_10M_1F_H2["Density [kg/m3]"].tolist()

# %%
from open_PROTEUS_csv import open_PROTEUS_csv

df_1 = open_PROTEUS_csv("H2_atmosphere_1_M_earth_1_F_earth - H2_atmosphere_1_M_earth_1_F_earth.csv")

df_2 = open_PROTEUS_csv("H2_atmosphere_10_M_earth_1_F_earth.csv", sep="\t")

df_3 = open_PROTEUS_csv("H2_atmosphere_1_M_earth_1000_F_earth.csv", sep="\t")

df_4 = open_PROTEUS_csv("H2_atmosphere_10_M_earth_1000_F_earth.csv", sep="\t")
# Out:
# C:\Users\rensk\BScProjectAtmosphericEscape\open_PROTEUS_csv.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   rho = rho[::-1]

# %%
df_2_dens, df_2_height = df_2

from radius_cutoffs import *
from figure14 import r, MT_Mp, r_min, r_cap, r_gi
r_min = r_min(df_2_dens, 2000, df_2_height)
r_cap = r_cap(df_2_dens, 2000, df_2_height, 118500600)
r_gi = r_gi(h, R)




plt.figure(figsize=(10,8))
plt.plot(r, MT_Mp, color='navy')
plt.xlabel('r [m]')
plt.axvline(r_min, label=r'$r_{min}$', color='tomato', linestyle='--', alpha=0.7)
plt.axvline(r_cap, label=r'$r_{cap}$', color='orange', linestyle='-.', alpha=0.7)
plt.axvline(r_gi,label=r'$r_{gi}$' , color='turquoise', linestyle=':', alpha=0.7)
plt.ylabel(r'$M_T/M_{earth}$')
plt.title(r'Total impactor mass $M_T$ needed to eject atmosphere as function of impactor radius r (fig 14)')
plt.xscale('log')
plt.yscale('log')
plt.legend()
# plt.savefig('Mtotal_vs_impactor_rad')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       3 from radius_cutoffs import *
#       4 from figure14 import r, MT_Mp, r_min, r_cap, r_gi
# ----> 5 r_min = r_min(df_2_dens, 2000, df_2_height)
#       6 r_cap = r_cap(df_2_dens, 2000, df_2_height, 118500600)
#       7 r_gi = r_gi(h, R)
#
# TypeError: 'float' object is not callable

# %%
# df_10M_1000F_H2 = pd.read_csv("H2_atmosphere_10_M_earth_1000_F_earth.csv")
#rho_H2_10M_1000F = df_10M_1000F_H2["Density [kg/m3]"].tolist()

# %% [markdown]
# # FIX M_atm, integrate per shell, r^3

# %%
# if r > r_gi

from giant_impacts_fractional_loss import x, X_loss
from Earth_constants import M


gamma_adi = 4/3
gamma_iso = 5/3

#should be multiplied by atmosphere mass, not planet mass
F1_M1_H2 = X_loss(x, gamma_adi) * M_atm_H2_1M_1F
F1_M10_H2 = X_loss(x, gamma_adi) #* M_cap
F1000_M1_H2 = X_loss(x, gamma_iso) #* M_cap
F1000_M10_H2 = X_loss(x, gamma_adi) #* M_cap

plt.figure(figsize=(10,8))
plt.plot(x, F1_M1_H2, color='navy', label='1M, 1F')
plt.plot(x, F1_M10_H2, color='navy', label='10M, 1F', linestyle='--')
plt.plot(x, F1000_M1_H2, color='red', label='1M, 1000F')
plt.plot(x, F1000_M10_H2, color='red', label='10M, 1000F', linestyle='--')
plt.xlabel(r'$v_{imp}m/v_{esc}M$')
plt.ylabel(r'$Mass loss (kg)$')
plt.title(r'Mass loss for H2 atmosphere')
plt.legend()
# plt.savefig('Mtotal_vs_impactor_rad')
plt.show()
