# %% [markdown]
# # BSc thesis: Impact-driven atmosphere escape
# ## The figures:

# %%
# %run Validation/frac_global_adia_vs_iso.py

# %%
# %run Plot_code/Global_loss_plot.py

# %%
# %run Plot_code/Planetesimal_loss_plot.py

# %%
# %run Plot_code/MLR_vs_Mpl_plot.py

# %%
# %run Plot_code/MLR_vs_q_plot.py

# %%
# %run Validation/Earth_total_impactor_mass_validation.py

# %%
# %run figure14.py
